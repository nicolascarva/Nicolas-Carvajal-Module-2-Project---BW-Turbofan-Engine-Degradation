# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
n_=['']*21
for i in range(0,21):
    n_[i]='sens_meas_'+str(i+1)
col_names=['unit_no', 'time', 'op_set1', 'op_set2', 'op_set3']+ n_

# %%
df=pd.read_csv('./data/train_FD001.txt', delimiter=" ", names=col_names, header=None, index_col=False)

# %%
# df=pd.read_csv('./data/train_FD001.txt', delimiter=" ")
df.head()
# Out:
#    unit_no  time  op_set1  op_set2  op_set3  sens_meas_1  sens_meas_2  \
# 0        1     1  -0.0007  -0.0004    100.0       518.67       641.82
# 1        1     2   0.0019  -0.0003    100.0       518.67       642.15
# 2        1     3  -0.0043   0.0003    100.0       518.67       642.35
# 3        1     4   0.0007   0.0000    100.0       518.67       642.35
# 4        1     5  -0.0019  -0.0002    100.0       518.67       642.37
#
#    sens_meas_3  sens_meas_4  sens_meas_5  ...  sens_meas_12  sens_meas_13  \
# 0      1589.70      1400.60        14.62  ...        521.66       2388.02
# 1      1591.82      1403.14        14.62  ...        522.28       2388.07
# 2      1587.99      1404.20        14.62  ...        522.42       2388.03
# 3      1582.79      1401.87        14.62  ...        522.86       2388.08
# 4      1582.85      1406.22        14.62  ...        522.19       2388.04
#
#    sens_meas_14  sens_meas_15  sens_meas_16  sens_meas_17  sens_meas_18  \
# ...

# %%
plt.scatter(df.loc[df['unit_no']==1,'time'], df.loc[df['unit_no']==1,'sens_meas_2'])
